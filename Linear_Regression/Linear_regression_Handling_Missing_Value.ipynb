# %%
import pandas as pd
import numpy as np
from sklearn.metrics import *
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %%
df= pd.read_csv("C:\\Users\\dhsup\\Downloads\\ChemicalProcess.csv")
df.head()
# Out:
#    Yield  BiologicalMaterial01  BiologicalMaterial02  BiologicalMaterial03  \
# 0  38.00                  6.25                 49.58                 56.97
# 1  42.44                  8.01                 60.97                 67.48
# 2  42.03                  8.01                 60.97                 67.48
# 3  41.42                  8.01                 60.97                 67.48
# 4  42.49                  7.47                 63.33                 72.25
#
#    BiologicalMaterial04  BiologicalMaterial05  BiologicalMaterial06  \
# 0                 12.74                 19.51                 43.73
# 1                 14.65                 19.36                 53.14
# 2                 14.65                 19.36                 53.14
# 3                 14.65                 19.36                 53.14
# 4                 14.02                 17.91                 54.66
#
#    BiologicalMaterial07  BiologicalMaterial08  BiologicalMaterial09  ...  \
# ...

# %%
df_dum = pd.get_dummies(df)

# %%
x=df_dum.drop("Yield",axis = 1)
y=df_dum["Yield"]

# %%
#spliting data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=24)

# %%
imp = SimpleImputer(strategy="mean").set_output(transform="pandas")
## train set opreation
x_trn_imp=imp.fit_transform(x_train)

# %%
model = LinearRegression()
model.fit(x_trn_imp,y_train)
# Out:
# LinearRegression()

# %%
x_test_imp = imp.transform(x_test)
y_pred=model.predict(x_test_imp)
